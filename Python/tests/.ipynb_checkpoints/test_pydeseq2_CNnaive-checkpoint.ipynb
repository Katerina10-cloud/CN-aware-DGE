# %%
import os
import pickle as pkl
import pandas as pd
import numpy as np

import pydeseq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats

# %%
# Loading the data from package
DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/CN-aware-DGE/Python/datasets/"
counts_df = pd.read_csv(os.path.join(DATA_PATH, "rna_counts_cnv.csv"), index_col=0)
counts_df = counts_df.T
metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata.csv"), index_col=0)

# %%
# Test real data
DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/TCGA/lung_cancer/LUAD/"
counts_df = pd.read_csv(os.path.join(DATA_PATH, "rna_test_2.csv"), index_col=0)
counts_df = counts_df.T
metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata_2.csv"), index_col=0)

# %%
#Data filtering
#genes_to_keep = counts_df.columns[counts_df.sum(axis=0) >= 10]
#counts_df = counts_df[genes_to_keep]
counts_df.shape
# Out:
# (46, 4521)

# %%
inference = DefaultInference(n_cpus=8)
dds = DeseqDataSet(
    counts=counts_df,
    metadata=metadata,
    design_factors="condition",
    refit_cooks=False,
    inference=inference,
)

# %%
dds.fit_size_factors()
# Out:
# Fitting size factors...
# ... done in 0.02 seconds.

# %%
dds.obsm["size_factors"]
# Out:
# array([0.67758446, 1.02045719, 0.54669702, 1.49009557, 0.82145671,
#        0.66637386, 0.74202577, 0.70415948, 0.82910315, 1.88952998,
#        0.80307518, 1.50263797, 1.24013763, 0.83638051, 0.71497536,
#        0.64487491, 0.85263563, 1.86936243, 0.97832601, 0.58529766,
#        1.00594883, 1.7390045 , 0.76037159, 1.35373578, 1.06762675,
#        0.73159263, 2.42596498, 1.17834825, 1.59054813, 0.72737468,
#        1.60828394, 1.11022136, 2.37081761, 0.85548454, 0.81632801,
#        0.96160257, 0.62399661, 0.53859099, 0.93368884, 0.76892275,
#        0.7360291 , 1.02691655, 0.62772752, 1.55734457, 2.06080947,
#        1.09874757])

# %%
dds.fit_genewise_dispersions()
# Out:
# Fitting dispersions...
# ... done in 0.48 seconds.

# %%
dds.varm["genewise_dispersions"]
# Out:
# array([0.25664889, 0.02629249, 0.07846112, ..., 0.08573993, 0.11982246,
#        0.111771  ])

# %%
dds.fit_dispersion_trend()
# Out:
# Fitting dispersion trend curve...
# ... done in 0.08 seconds.

# %%
#dds.uns["trend_coeffs"]
dds.varm["fitted_dispersions"]
# Out:
# array([0.17907225, 0.20099648, 0.19437097, ..., 0.22791215, 0.18784389,
#        0.21284132])

# %%
dds.fit_dispersion_prior()
print(
    f"logres_prior={dds.uns['_squared_logres']}, sigma_prior={dds.uns['prior_disp_var']}"
)
# Out:
# logres_prior=0.9363508508621136, sigma_prior=0.8898476016230555

# %%
dds.fit_MAP_dispersions()
# Out:
# Fitting MAP dispersions...
# ... done in 0.67 seconds.

# %%
dds.varm["MAP_dispersions"]
# Out:
# array([0.25256755, 0.0291794 , 0.08199168, ..., 0.08993242, 0.12239759,
#        0.11527167])

# %%
dds.varm["dispersions"]
# Out:
# array([0.25256755, 0.0291794 , 0.08199168, ..., 0.08993242, 0.12239759,
#        0.11527167])

# %%
dds.fit_LFC()
# Out:
# Fitting LFCs...
# ... done in 0.39 seconds.

# %%
dds.varm["LFC"]
# Out:
#         intercept  condition_B_vs_A
# A2M     11.970843         -0.839222
# AAMP     8.198560          0.275190
# AARS1    8.439227          0.450130
# AATF     7.569514          0.420987
# AATK     7.554746         -1.222733
# ...           ...               ...
# ZNFX1    8.612819         -0.173029
# ZNHIT1   7.791207          0.181003
# ZPR1     7.446191          0.225586
# ZYX      9.367114         -0.349858
# ZZEF1    8.084625         -0.345427
#
# [4521 rows x 2 columns]

# %%
# Statistical analysis
stat_res = DeseqStats(dds, alpha=0.05, cooks_filter=False, independent_filter=True)

# %%
stat_res.run_wald_test()
# Out:
# Running Wald tests...
# ... done in 0.25 seconds.

# %%
stat_res.p_values
# Out:
# A2M       4.141595e-09
# A4GALT    2.789288e-01
# AAAS      1.077033e-04
# AACS      1.713722e-04
# AADAC     7.135731e-05
#               ...
# ZXDC      3.453243e-02
# ZYG11B    7.309959e-02
# ZYX       6.517050e-04
# ZZEF1     2.546688e-04
# ZZZ3      3.210599e-06
# Length: 9042, dtype: float64

# %%
# p-value adjustment

if stat_res.independent_filter:
    stat_res._independent_filtering()
else:
    stat_res._p_value_adjustment()

stat_res.padj
# Out:
# A2M       6.964531e-08
# AAMP      2.305374e-07
# AARS1     4.173015e-07
# AATF      4.837913e-09
# AATK      1.881091e-09
#               ...
# ZNFX1     1.028647e-01
# ZNHIT1    1.417398e-01
# ZPR1      1.916124e-02
# ZYX       1.543231e-03
# ZZEF1     1.285476e-03
# Name: 0, Length: 4521, dtype: float64

# %%
stat_res.summary()
# Out:
# Log2 fold change & Wald test p-value: condition B vs A
#              baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M     113187.331352       -1.210741  0.213808 -5.662751  1.489649e-08
# AAMP      4211.653353        0.397016  0.072999  5.438619  5.369517e-08
# AARS1     5939.898973        0.649401  0.121962  5.324621  1.011640e-07
# AATF      2445.671459        0.607356  0.099057  6.131406  8.710597e-10
# AATK      1235.957750       -1.764030  0.280477 -6.289390  3.187161e-10
# ...               ...             ...       ...       ...           ...
# ZNFX1     5064.452549       -0.249628  0.138311 -1.804826  7.110199e-02
# ZNHIT1    2659.129624        0.261132  0.159655  1.635599  1.019235e-01
# ZPR1      1930.191950        0.325452  0.127985  2.542887  1.099408e-02
# ZYX       9970.501959       -0.504738  0.148905 -3.389672  6.997618e-04
# ZZEF1     2770.533005       -0.498346  0.144689 -3.444248  5.726496e-04
#
#                 padj
# A2M     6.964531e-08
# AAMP    2.305374e-07
# AARS1   4.173015e-07
# AATF    4.837913e-09
# AATK    1.881091e-09
# ...              ...
# ZNFX1   1.028647e-01
# ZNHIT1  1.417398e-01
# ZPR1    1.916124e-02
# ZYX     1.543231e-03
# ZZEF1   1.285476e-03
#
# [4521 rows x 6 columns]

# %%
stat_res.plot_MA(s=10)

# %%
stat_res.lfc_shrink(coeff="condition_B_vs_A")
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition B vs A
#              baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# A2M     113187.331352        0.824310  0.220384 -5.662751  1.489649e-08
# AAMP      4211.653353        0.383021  0.072967  5.438619  5.369517e-08
# AARS1     5939.898973        0.628633  0.122455  5.324621  1.011640e-07
# AATF      2445.671459        0.589377  0.099010  6.131406  8.710597e-10
# AATK      1235.957750       -1.646673  0.281677 -6.289390  3.187161e-10
# ...               ...             ...       ...       ...           ...
# ZNFX1     5064.452549       -0.235582  0.137043 -1.804826  7.110199e-02
# ZNHIT1    2659.129624        0.240913  0.157972  1.635599  1.019235e-01
# ZPR1      1930.191950        0.310167  0.127154  2.542887  1.099408e-02
# ZYX       9970.501959       -0.485233  0.150203 -3.389672  6.997618e-04
# ZZEF1     2770.533005       -0.482643  0.144140 -3.444248  5.726496e-04
#
#                 padj
# A2M     6.964531e-08
# AAMP    2.305374e-07
# AARS1   4.173015e-07
# AATF    4.837913e-09
# AATK    1.881091e-09
# ...              ...
# ZNFX1   1.028647e-01
# ZNHIT1  1.417398e-01
# ZPR1    1.916124e-02
# ZYX     1.543231e-03
# ZZEF1   1.285476e-03
#
# [4521 rows x 6 columns]
# ... done in 0.55 seconds.

# %%
stat_res.plot_MA(s=10)

# %%
#Save results
OUTPUT_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/CN-aware-DGE/Python/results"
os.makedirs(OUTPUT_PATH, exist_ok=True)  # Create path if it doesn't exist
stat_res.results_df.to_csv(os.path.join(OUTPUT_PATH, "res_CNnaive_test2.csv"))

# %%
import os
import pickle as pkl
import pandas as pd
import numpy as np

from pydeseq2.utils import build_design_matrix
#from pydeseq2.dds import DeseqDataSet
#from pydeseq2.default_inference import DefaultInference
#from pydeseq2.ds import DeseqStats

# %%
# Loading the data from package

# %%
# Test simulated data
#DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/CN-aware-DGE/Python/datasets/"
#counts_df = pd.read_csv(os.path.join(DATA_PATH, "rna_counts_cnv_v2.csv"), index_col=0)
#counts_df = counts_df.T
#metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata_v2.csv"), index_col=0)
#cnv = pd.read_csv(os.path.join(DATA_PATH, "cnv_v2.csv"), index_col=0)
#cnv = cnv.T

# %%
# Test real data
DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/TCGA/colon/test"
counts_df = pd.read_csv(os.path.join(DATA_PATH, "rna_test.csv"), index_col=0)
counts_df = counts_df.T
metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata.csv"), index_col=0)
cnv = pd.read_csv(os.path.join(DATA_PATH, "cnv_test.csv"), index_col=0)
cnv = cnv.T

# %%
from dds import pydeseq2CN_data
from inference import Inference
from def_inference import DefInference
import utils_pydeseq2CN

# %%
inference = DefInference(n_cpus=8)
dds = pydeseq2CN_data(
    counts=counts_df,
    metadata=metadata,
    cnv=cnv,
    design_factors="condition",
    inference=inference,
    refit_cooks=True
)

# %%
dds.fit_size_factors()
dds.fit_genewise_dispersions()
dds.fit_dispersion_trend()
dds.fit_dispersion_prior()
dds.fit_MAP_dispersions()
dds.fit_LFC()
# Out:
# Fitting size factors...
# ... done in 0.01 seconds.
#
# Fitting dispersions...
# ... done in 0.46 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.06 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.52 seconds.
#
# Fitting LFCs...
# ... done in 0.26 seconds.

# %%
#dds.obsm["size_factors"]
#dds.varm["fitted_dispersions"]
#print(
    #f"logres_prior={dds.uns['_squared_logres']}, sigma_prior={dds.uns['prior_disp_var']}"
#)
#dds.varm["MAP_dispersions"]
#dds.varm["LFC"]

# %%
dds.calculate_cooks()
if dds.refit_cooks:
    # Replace outlier counts
    dds.refit()
# Out:
# replace_mask before filtering: (24, 154)
# Number of True values in replace_mask: 154
# replacement_counts_trimmed shape: (9, 154)
# Calculating cook's distance...
# ... done in 0.03 seconds.
#
# Replacing 154 outlier genes.
#
# Fitting dispersions...
# ... done in 0.04 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.04 seconds.
#
# Fitting LFCs...
# ... done in 0.03 seconds.

# %%
# Statistical test

# %%
import dds_stat
from dds_stat import pydeseq2CN_Stats

# %%
# Statistical analysis
stat_res = pydeseq2CN_Stats(dds, alpha=0.05, independent_filter=True, cooks_filter=True)
stat_res.run_wald_test()
# Out:
# Running Wald tests...
# ... done in 0.13 seconds.

# %%
stat_res.p_values
# Out:
# TSPAN6     9.076929e-01
# CFH        3.962587e-04
# FUCA2      6.378519e-01
# NIPAL3     1.608254e-01
# ENPP4      9.253188e-03
#                ...
# PSMB3      3.133400e-04
# CISD3      6.074365e-01
# IGLV2-8    2.681705e-03
# GGNBP2     1.004900e-01
# DHRS11     2.444527e-15
# Length: 4529, dtype: float64

# %%
if stat_res.independent_filter:
    stat_res._independent_filtering()
else:
    stat_res._p_value_adjustment()

stat_res.padj
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pydeseq2/utils.py:1599: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   beta = np.linalg.lstsq(A, b)[0]
# TSPAN6     9.326092e-01
# CFH        1.387978e-03
# FUCA2      7.234739e-01
# NIPAL3     2.518597e-01
# ENPP4      2.226351e-02
#                ...
# PSMB3      1.122719e-03
# CISD3      6.994864e-01
# IGLV2-8    7.590902e-03
# GGNBP2     1.725244e-01
# DHRS11     6.016991e-14
# Name: 0, Length: 4529, dtype: float64

# %%
stat_res.summary()
# Out:
# Log2 fold change & Wald test p-value: condition B vs A
#             baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# TSPAN6   4353.725376        0.034409  0.296757  0.115949  9.076929e-01
# CFH      1140.275328       -1.067840  0.301431 -3.542563  3.962587e-04
# FUCA2    1942.166886        0.060986  0.129563  0.470704  6.378519e-01
# NIPAL3   2155.205004       -0.220056  0.156925 -1.402301  1.608254e-01
# ENPP4    1107.187210       -0.639346  0.245661 -2.602555  9.253188e-03
# ...              ...             ...       ...       ...           ...
# PSMB3    4517.122824        0.860265  0.238696  3.604014  3.133400e-04
# CISD3    2722.258624       -0.157013  0.305630 -0.513736  6.074365e-01
# IGLV2-8  1626.669273       -1.918923  0.639205 -3.002047  2.681705e-03
# GGNBP2   2163.392194       -0.202861  0.123509 -1.642483  1.004900e-01
# DHRS11   4074.947054       -2.651292  0.334911 -7.916417  2.444527e-15
#
#                  padj
# TSPAN6   9.326092e-01
# CFH      1.387978e-03
# FUCA2    7.234739e-01
# NIPAL3   2.518597e-01
# ENPP4    2.226351e-02
# ...               ...
# PSMB3    1.122719e-03
# CISD3    6.994864e-01
# IGLV2-8  7.590902e-03
# GGNBP2   1.725244e-01
# DHRS11   6.016991e-14
#
# [4529 rows x 6 columns]

# %%
stat_res.plot_MA(s=10)

# %%
stat_res.lfc_shrink(coeff="condition_B_vs_A")
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition B vs A
#             baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# TSPAN6   4353.725376        0.002155  0.286950  0.115949  9.076929e-01
# CFH      1140.275328       -0.973168  0.300085 -3.542563  3.962587e-04
# FUCA2    1942.166886        0.062629  0.128267  0.470704  6.378519e-01
# NIPAL3   2155.205004       -0.207606  0.155268 -1.402301  1.608254e-01
# ENPP4    1107.187210       -0.588874  0.242692 -2.602555  9.253188e-03
# ...              ...             ...       ...       ...           ...
# PSMB3    4517.122824        0.794976  0.237691  3.604014  3.133400e-04
# CISD3    2722.258624       -0.182504  0.296034 -0.513736  6.074365e-01
# IGLV2-8  1626.669273       -1.516316  0.655797 -3.002047  2.681705e-03
# GGNBP2   2163.392194       -0.193338  0.122539 -1.642483  1.004900e-01
# DHRS11   4074.947054       -2.521113  0.338340 -7.916417  2.444527e-15
#
#                  padj
# TSPAN6   9.326092e-01
# CFH      1.387978e-03
# FUCA2    7.234739e-01
# NIPAL3   2.518597e-01
# ENPP4    2.226351e-02
# ...               ...
# PSMB3    1.122719e-03
# CISD3    6.994864e-01
# IGLV2-8  7.590902e-03
# GGNBP2   1.725244e-01
# DHRS11   6.016991e-14
#
# [4529 rows x 6 columns]
# ... done in 0.57 seconds.

# %%
stat_res.summary()
# Out:
# Log2 fold change & Wald test p-value: condition B vs A
#             baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# TSPAN6   4353.725376        0.002155  0.286950  0.115949  9.076929e-01
# CFH      1140.275328       -0.973168  0.300085 -3.542563  3.962587e-04
# FUCA2    1942.166886        0.062629  0.128267  0.470704  6.378519e-01
# NIPAL3   2155.205004       -0.207606  0.155268 -1.402301  1.608254e-01
# ENPP4    1107.187210       -0.588874  0.242692 -2.602555  9.253188e-03
# ...              ...             ...       ...       ...           ...
# PSMB3    4517.122824        0.794976  0.237691  3.604014  3.133400e-04
# CISD3    2722.258624       -0.182504  0.296034 -0.513736  6.074365e-01
# IGLV2-8  1626.669273       -1.516316  0.655797 -3.002047  2.681705e-03
# GGNBP2   2163.392194       -0.193338  0.122539 -1.642483  1.004900e-01
# DHRS11   4074.947054       -2.521113  0.338340 -7.916417  2.444527e-15
#
#                  padj
# TSPAN6   9.326092e-01
# CFH      1.387978e-03
# FUCA2    7.234739e-01
# NIPAL3   2.518597e-01
# ENPP4    2.226351e-02
# ...               ...
# PSMB3    1.122719e-03
# CISD3    6.994864e-01
# IGLV2-8  7.590902e-03
# GGNBP2   1.725244e-01
# DHRS11   6.016991e-14
#
# [4529 rows x 6 columns]

# %%
stat_res.plot_MA(s=10)

# %%
OUTPUT_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/CN-aware-DGE/Python/results/COAD"
os.makedirs(OUTPUT_PATH, exist_ok=True)  # Create path if it doesn't exist
stat_res.results_df.to_csv(os.path.join(OUTPUT_PATH, "res_CNaware_test.csv"))
